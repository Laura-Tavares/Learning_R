# %% [markdown]
# # Boxplot
#
# Boxplots are a measure of how well distributed is the data in a data set. It divides the data set into three quartiles. This graph represents the **minimum**, **maximum**, **median**, **first quartile** and **third quartile** in the data set. It is also useful in comparing the distribution of data across data sets by drawing boxplots for each of them.
#
# ## Explaining boxplot
#
# - The box indicates the range in which the middle 50% of all data lies
#
# - The lower end of the plot is the first quartile and the upper end is the third quartile
#
# - The solid line indicates the median and the dashed line indicates the mean
#
# - The T shaped go to the last point which is still within 1.5 times the interquartile range
#
# - Points that are further away are considered outliers
#
# ## Synthax
# *boxplot(x, data, notch, varwidth, names, main)*
#
# ## Parameters
#
# - **x** is a vector or a formula.
#
# - **data** is the data frame.
#
# - **notch** is a logical value. Set as TRUE to draw a notch.
#
# - **varwidth** is a logical value. Set as true to draw width of the box proportionate to the sample size.
#
# - **names** are the group labels which will be printed under each boxplot.
#
# - **main** is used to give a title to the graph.

# %%
data(iris)
head
# Out:
# function (x, ...)
# UseMethod("head")
# <bytecode: 0x2e390d0>
# <environment: namespace:utils>

# %%
input <- mtcars
head (input)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %%
input <- mtcars[,c('mpg','cyl')]

# mpg ~ cyl - specify the columns of the data sets

boxplot(mpg ~ cyl, data = mtcars, xlab = "Number of Cylinders",
   ylab = "Miles Per Gallon", main = "Mileage Data")
# Out:
# Plot with title “Mileage Data”

# %%
# Testing library to use in example

library (MASS)
View(ldeaths)
# Out:
#      Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 1974 3035 2552 2704 2554 2014 1655 1721 1524 1596 2074 2199 2512
# 1975 2933 2889 2938 2497 1870 1726 1607 1545 1396 1787 2076 2837
# 1976 2787 3891 3179 2011 1636 1580 1489 1300 1356 1653 2013 2823
# 1977 3102 2294 2385 2444 1748 1554 1498 1361 1346 1564 1640 2293
# 1978 2815 3137 2679 1969 1870 1633 1529 1366 1357 1570 1535 2491
# 1979 3084 2605 2573 2143 1693 1504 1461 1354 1333 1492 1781 1915

# %%
library (MASS)

boxplot (ldeaths,
        main = "Monthly Deaths from Lung Diseases in the UK",
        ylab = "Number of deaths")
# Out:
# Plot with title “Monthly Deaths from Lung Diseases in the UK”

# %%
# Testing library to use as example

library(MASS)
head(UScereal)
# Out:
# Warning message:
# “package ‘MASS’ was built under R version 4.2.1”
#                           mfr calories protein   fat      sodium   fibre
# 100% Bran                 N   212.1212 12.121212 3.030303 393.9394 30.303030
# All-Bran                  K   212.1212 12.121212 3.030303 787.8788 27.272727
# All-Bran with Extra Fiber K   100.0000  8.000000 0.000000 280.0000 28.000000
# Apple Cinnamon Cheerios   G   146.6667  2.666667 2.666667 240.0000  2.000000
# Apple Jacks               K   110.0000  2.000000 0.000000 125.0000  1.000000
# Basic 4                   G   173.3333  4.000000 2.666667 280.0000  2.666667
#                           carbo    sugars   shelf potassium vitamins
# 100% Bran                 15.15152 18.18182 3     848.48485 enriched
# All-Bran                  21.21212 15.15151 3     969.69697 enriched
# All-Bran with Extra Fiber 16.00000  0.00000 3     660.00000 enriched
# Apple Cinnamon Cheerios   14.00000 13.33333 1      93.33333 enriched
# ...

# %%
library(MASS)

boxplot(UScereal$sodium, 
        main = "Sodium Content in One Cup of US Cereal", 
        ylab = "Sodium Content (in milligrams)")
# Out:
# Plot with title “Sodium Content in One Cup of US Cereal”

# %%
input <- mtcars[,c('mpg','cyl')]

boxplot ( mpg ~ cyl, data = mtcars, 
        xlab = "X_Testing", 
        ylab = "Y_testing", 
        main = "Basic boxplot",
        varwidth = TRUE, 
        col = c("lightgreen","lightblue","pink"),
        names = c("High","Medium","Low")
)
# Out:
# Plot with title “Basic boxplot”

# %% [markdown]
# ## Boxplot with Notch
#
# ![image.png](attachment:72c0545a-43ef-4bce-8c41-b8e8dfcd11d9.png)

# %% [markdown]
# ## Using ggplot
#
# - **ggplot(data = data_frame, aes (y = vector))** – initializes a ggplot object
# - **geom_boxplot( )** – geometric shape to make a boxplot
# - **scale_x_discrete( )** - leave the argument empty to remove extraneous numbers on the x-axis and to contract the boxplot otherwise the boxplot is very wide
# - **lab( )** - for labelling
# - **coord_flip( )** - draws a horizontal boxplot

# %%
library(ggplot2)
library(MASS)

ggplot(data = UScereal, aes(y = sodium)) + 
  geom_boxplot() + 
  scale_x_discrete() +
  labs(title = "Sodium Content in One Cup of US Cereal",
       y = "Sodium Content (in milligrams)")
# Out:
# plot without title
